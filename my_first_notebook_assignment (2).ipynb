# %% [markdown]
# what is difference between softwatre and hardware?
#
# Hardware
# Physical parts of a computer you can see and touch
# Examples:
# Keyboard,Mouse,Monitor ,Hard drive
# Hardware is the body of the computer
#
# Software
# Programs or instructions that tell the hardware what to do
# You cannot touch it
# Examples:
# Microsoft Windows
# Google Chrome
# Games and apps
# Software is the brain of the computer
