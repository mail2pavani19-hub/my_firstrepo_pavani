# %%
telugu=int(input())
print("telugu:",telugu )
hindi=int(input())
print("hindi:",hindi)
maths=int(input())
print("maths:",maths)
science=int(input())
print("science:",science)
social=int(input())
print("social:",social)
n=telugu + hindi + maths + science + social
print("total: ",n)
average=n/3
print("average :",average)
# Out:
# 56
# telugu: 56
# 67
# hindi: 67
# 89
# maths: 89
# 56
# science: 56
# 67
# social: 67
# total:  335
# average : 111.66666666666667

# %%
telugu=input()
b=20
print(telugu+b)
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2976/2567632028.py in <cell line: 0>()
#       1 telugu=input()
#       2 b=20
# ----> 3 print(telugu+b)
#
# TypeError: can only concatenate str (not "int") to str
